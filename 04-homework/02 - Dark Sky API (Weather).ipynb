# %% [markdown]
# # Dark Sky API (Weather)
#
# Answer the following questions using the [Dark Sky API](https://darksky.net/dev/). I've added three cells for each question but you're free to use more or less! Hold `Shift` and hit `Enter` to run a cell, and use the `+` on the top left to add a new cell to a notebook.
#
# If you spend some time reading the documentation your life will probably be a little bit easier!
#
# ## 0) Import any libraries you might need
#
# - *Tip: We're going to be downloading things from the internet, so we probably need `requests`.*

# %%
import requests

# %%
response = requests.get('https://api.darksky.net/forecast/e7002f92280bca0fccdbd6dd1fe42971/37.8267,-122.4233')
data = response.json()

# %%
data.keys()
# Out:
# dict_keys(['latitude', 'longitude', 'timezone', 'currently', 'minutely', 'hourly', 'daily', 'alerts', 'flags', 'offset'])

# %% [markdown]
# ## 1) Make a request from the Dark Sky API for where you were born (or lived, or want to visit!).
#
# - *Tip: The URL we used in class was for a place near San Francisco. What was the format of the endpoint that made this happen?*
# - *Tip: Save the URL as a separate variable, and be sure to not have `[` and `]` inside.*
# - *Tip: How is north vs. south and east vs. west latitude/longitude represented? Is it the normal North/South/East/West?*
# - *Tip: You know it's JSON, but Python doesn't! Make sure you aren't trying to deal with plain text.*
# - *Tip: Once you've imported the JSON into a variable, check the timezone's name to make sure it seems like it got the right part of the world!*

# %%
response = requests.get('https://api.darksky.net/forecast/e7002f92280bca0fccdbd6dd1fe42971/64.1466,-21.9426')
Reykjavik = response.json()
Reykjavik['currently']
# Out:
# {'time': 1560204285,
#  'summary': 'Partly Cloudy',
#  'icon': 'partly-cloudy-day',
#  'precipIntensity': 0,
#  'precipProbability': 0,
#  'temperature': 50.38,
#  'apparentTemperature': 50.38,
#  'dewPoint': 42.77,
#  'humidity': 0.75,
#  'pressure': 1033.41,
#  'windSpeed': 5.6,
#  'windGust': 7.16,
#  'windBearing': 297,
#  'cloudCover': 0.38,
#  'uvIndex': 0,
#  'visibility': 6.29,
#  'ozone': 337.08}

# %% [markdown]
# ## 2) What's the current wind speed? How much warmer does it feel than it actually is?
#
# - *Tip: You can do this by browsing through the dictionaries, but it might be easier to read the documentation*
# - *Tip: For the second half: it **is** one temperature, and it **feels** a different temperature. Calculate the difference.*

# %%
Reykjavik['currently']['windSpeed']
# Out:
# 6.16

# %%
Reykjavik['currently']['temperature'] - data ['currently']['apparentTemperature']
# Out:
# -34.60999999999999

# %% [markdown]
# ## 3) Today's forecast is the FIRST daily forecast. For the place you decided on above, how much of the moon is currently visible?
#
# - *Tip: This does **not** use the `currently` key.*
# - *Tip: It might be helpful to save the forecast into its own variable*

# %%
Reykjavik
# Out:
# {'latitude': 64.1466,
#  'longitude': -21.9426,
#  'timezone': 'Atlantic/Reykjavik',
#  'currently': {'time': 1560202856,
#   'summary': 'Partly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0,
#   'precipProbability': 0,
#   'temperature': 50.88,
#   'apparentTemperature': 50.88,
#   'dewPoint': 42.61,
#   'humidity': 0.73,
#   'pressure': 1033.35,
#   'windSpeed': 6.16,
#   'windGust': 7.61,
#   'windBearing': 294,
#   'cloudCover': 0.38,
#   'uvIndex': 0,
#   'visibility': 6.22,
#   'ozone': 337.87},
#  'hourly': {'summary': 'Partly cloudy starting tomorrow morning.',
#   'icon': 'partly-cloudy-day',
#   'data': [{'time': 1560200400,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 51.75,
#     'apparentTemperature': 51.75,
#     'dewPoint': 42.3,
#     'humidity': 0.7,
#     'pressure': 1033.23,
#     'windSpeed': 7.07,
#     'windGust': 8.31,
#     'windBearing': 290,
#     'cloudCover': 0.38,
#     'uvIndex': 0,
#     'visibility': 6.22,
#     'ozone': 339.09},
#    {'time': 1560204000,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 50.48,
#     'apparentTemperature': 50.48,
#     'dewPoint': 42.74,
#     'humidity': 0.75,
#     'pressure': 1033.41,
#     'windSpeed': 5.74,
#     'windGust': 7.28,
#     'windBearing': 296,
#     'cloudCover': 0.38,
#     'uvIndex': 0,
#     'visibility': 6.22,
#     'ozone': 337.29},
#    {'time': 1560207600,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 49.18,
#     'apparentTemperature': 47.89,
#     'dewPoint': 43.06,
#     'humidity': 0.79,
#     'pressure': 1033.39,
#     'windSpeed': 4.04,
#     'windGust': 5.75,
#     'windBearing': 308,
#     'cloudCover': 0.34,
#     'uvIndex': 0,
#     'visibility': 7.13,
#     'ozone': 334.53},
#    {'time': 1560211200,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 48.09,
#     'apparentTemperature': 48.09,
#     'dewPoint': 42.11,
#     'humidity': 0.8,
#     'pressure': 1033.48,
#     'windSpeed': 2.92,
#     'windGust': 4.33,
#     'windBearing': 323,
#     'cloudCover': 0.14,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 331.76},
#    {'time': 1560214800,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 47.13,
#     'apparentTemperature': 47.13,
#     'dewPoint': 41.13,
#     'humidity': 0.8,
#     'pressure': 1033.81,
#     'windSpeed': 2.35,
#     'windGust': 3.15,
#     'windBearing': 333,
#     'cloudCover': 0.04,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 329.32},
#    {'time': 1560218400,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 46.17,
#     'apparentTemperature': 46.17,
#     'dewPoint': 40.72,
#     'humidity': 0.81,
#     'pressure': 1034.26,
#     'windSpeed': 1.75,
#     'windGust': 2.11,
#     'windBearing': 342,
#     'cloudCover': 0.09,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 326.98},
#    {'time': 1560222000,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 45.37,
#     'apparentTemperature': 45.37,
#     'dewPoint': 40.42,
#     'humidity': 0.83,
#     'pressure': 1034.65,
#     'windSpeed': 1.26,
#     'windGust': 1.58,
#     'windBearing': 357,
#     'cloudCover': 0.14,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 324.96},
#    {'time': 1560225600,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 45.17,
#     'apparentTemperature': 45.17,
#     'dewPoint': 40.48,
#     'humidity': 0.84,
#     'pressure': 1034.93,
#     'windSpeed': 1.18,
#     'windGust': 1.41,
#     'windBearing': 319,
#     'cloudCover': 0.18,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 323.59},
#    {'time': 1560229200,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 45.51,
#     'apparentTemperature': 45.51,
#     'dewPoint': 40.66,
#     'humidity': 0.83,
#     'pressure': 1035.11,
#     'windSpeed': 1.24,
#     'windGust': 1.48,
#     'windBearing': 305,
#     'cloudCover': 0.23,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 322.6},
#    {'time': 1560232800,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 46.31,
#     'apparentTemperature': 46.31,
#     'dewPoint': 40.69,
#     'humidity': 0.81,
#     'pressure': 1035.36,
#     'windSpeed': 1.29,
#     'windGust': 1.57,
#     'windBearing': 320,
#     'cloudCover': 0.27,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 321.58},
#    {'time': 1560236400,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0002,
#     'precipProbability': 0.02,
#     'precipType': 'rain',
#     'temperature': 47.7,
#     'apparentTemperature': 47.7,
#     'dewPoint': 40.36,
#     'humidity': 0.76,
#     'pressure': 1035.63,
#     'windSpeed': 0.39,
#     'windGust': 1.56,
#     'windBearing': 10,
#     'cloudCover': 0.32,
#     'uvIndex': 1,
#     'visibility': 10,
#     'ozone': 320.34},
#    {'time': 1560240000,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0002,
#     'precipProbability': 0.02,
#     'precipType': 'rain',
#     'temperature': 49.51,
#     'apparentTemperature': 49.51,
#     'dewPoint': 39.88,
#     'humidity': 0.69,
#     'pressure': 1035.91,
#     'windSpeed': 1.21,
#     'windGust': 1.61,
#     'windBearing': 236,
#     'cloudCover': 0.38,
#     'uvIndex': 1,
#     'visibility': 10,
#     'ozone': 319.09},
#    {'time': 1560243600,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0003,
#     'precipProbability': 0.02,
#     'precipType': 'rain',
#     'temperature': 51.36,
#     'apparentTemperature': 51.36,
#     'dewPoint': 39.4,
#     'humidity': 0.64,
#     'pressure': 1036.2,
#     'windSpeed': 1.62,
#     'windGust': 1.89,
#     'windBearing': 266,
#     'cloudCover': 0.42,
#     'uvIndex': 2,
#     'visibility': 10,
#     'ozone': 317.78},
#    {'time': 1560247200,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0002,
#     'precipProbability': 0.02,
#     'precipType': 'rain',
#     'temperature': 52.77,
#     'apparentTemperature': 52.77,
#     'dewPoint': 38.94,
#     'humidity': 0.59,
#     'pressure': 1036.45,
#     'windSpeed': 2.26,
#     'windGust': 2.49,
#     'windBearing': 277,
#     'cloudCover': 0.54,
#     'uvIndex': 3,
#     'visibility': 10,
#     'ozone': 316.39},
#    {'time': 1560250800,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0003,
#     'precipProbability': 0.02,
#     'precipType': 'rain',
#     'temperature': 54.2,
#     'apparentTemperature': 54.2,
#     'dewPoint': 38.51,
#     'humidity': 0.55,
#     'pressure': 1036.7,
#     'windSpeed': 2.87,
#     'windGust': 3.35,
#     'windBearing': 245,
#     'cloudCover': 0.7,
#     'uvIndex': 3,
#     'visibility': 10,
#     'ozone': 314.91},
#    {'time': 1560254400,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0004,
#     'precipProbability': 0.02,
#     'precipType': 'rain',
#     'temperature': 55.45,
#     'apparentTemperature': 55.45,
#     'dewPoint': 38.23,
#     'humidity': 0.52,
#     'pressure': 1036.94,
#     'windSpeed': 4.02,
#     'windGust': 4.26,
#     'windBearing': 253,
#     'cloudCover': 0.77,
#     'uvIndex': 4,
#     'visibility': 10,
#     'ozone': 313.3},
#    {'time': 1560258000,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0003,
#     'precipProbability': 0.02,
#     'precipType': 'rain',
#     'temperature': 56.79,
#     'apparentTemperature': 56.79,
#     'dewPoint': 38.12,
#     'humidity': 0.5,
#     'pressure': 1037.13,
#     'windSpeed': 4.86,
#     'windGust': 5.11,
#     'windBearing': 257,
#     'cloudCover': 0.69,
#     'uvIndex': 4,
#     'visibility': 10,
#     'ozone': 311.53},
#    {'time': 1560261600,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0003,
#     'precipProbability': 0.02,
#     'precipType': 'rain',
#     'temperature': 57.42,
#     'apparentTemperature': 57.42,
#     'dewPoint': 38.15,
#     'humidity': 0.48,
#     'pressure': 1037.31,
#     'windSpeed': 5.6,
#     'windGust': 5.91,
#     'windBearing': 255,
#     'cloudCover': 0.54,
#     'uvIndex': 4,
#     'visibility': 10,
#     'ozone': 309.7},
#    {'time': 1560265200,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0002,
#     'precipProbability': 0.02,
#     'precipType': 'rain',
#     'temperature': 57.67,
#     'apparentTemperature': 57.67,
#     'dewPoint': 38.28,
#     'humidity': 0.48,
#     'pressure': 1037.5,
#     'windSpeed': 6.15,
#     'windGust': 6.46,
#     'windBearing': 252,
#     'cloudCover': 0.42,
#     'uvIndex': 4,
#     'visibility': 10,
#     'ozone': 308.04},
#    {'time': 1560268800,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 57.27,
#     'apparentTemperature': 57.27,
#     'dewPoint': 38.51,
#     'humidity': 0.49,
#     'pressure': 1037.71,
#     'windSpeed': 6.59,
#     'windGust': 6.71,
#     'windBearing': 243,
#     'cloudCover': 0.4,
#     'uvIndex': 4,
#     'visibility': 10,
#     'ozone': 306.49},
#    {'time': 1560272400,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 56.48,
#     'apparentTemperature': 56.48,
#     'dewPoint': 38.84,
#     'humidity': 0.52,
#     'pressure': 1037.92,
#     'windSpeed': 5.95,
#     'windGust': 6.71,
#     'windBearing': 265,
#     'cloudCover': 0.42,
#     'uvIndex': 3,
#     'visibility': 10,
#     'ozone': 305.14},
#    {'time': 1560276000,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 55.37,
#     'apparentTemperature': 55.37,
#     'dewPoint': 39.25,
#     'humidity': 0.55,
#     'pressure': 1038.12,
#     'windSpeed': 6.08,
#     'windGust': 6.39,
#     'windBearing': 257,
#     'cloudCover': 0.46,
#     'uvIndex': 2,
#     'visibility': 10,
#     'ozone': 304.19},
#    {'time': 1560279600,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 54.66,
#     'apparentTemperature': 54.66,
#     'dewPoint': 39.85,
#     'humidity': 0.57,
#     'pressure': 1038.39,
#     'windSpeed': 5.21,
#     'windGust': 5.56,
#     'windBearing': 254,
#     'cloudCover': 0.58,
#     'uvIndex': 1,
#     'visibility': 10,
#     'ozone': 304.03},
#    {'time': 1560283200,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 53.3,
#     'apparentTemperature': 53.3,
#     'dewPoint': 40.55,
#     'humidity': 0.62,
#     'pressure': 1038.64,
#     'windSpeed': 3.96,
#     'windGust': 4.4,
#     'windBearing': 272,
#     'cloudCover': 0.72,
#     'uvIndex': 1,
#     'visibility': 10,
#     'ozone': 304.33},
#    {'time': 1560286800,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 52.16,
#     'apparentTemperature': 52.16,
#     'dewPoint': 41.14,
#     'humidity': 0.66,
#     'pressure': 1038.91,
#     'windSpeed': 3.15,
#     'windGust': 3.47,
#     'windBearing': 272,
#     'cloudCover': 0.84,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 304.63},
#    {'time': 1560290400,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 51.24,
#     'apparentTemperature': 51.24,
#     'dewPoint': 41.55,
#     'humidity': 0.69,
#     'pressure': 1039.14,
#     'windSpeed': 2.73,
#     'windGust': 3.12,
#     'windBearing': 276,
#     'cloudCover': 0.91,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 304.87},
#    {'time': 1560294000,
#     'summary': 'Overcast',
#     'icon': 'cloudy',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 50.56,
#     'apparentTemperature': 50.56,
#     'dewPoint': 41.84,
#     'humidity': 0.72,
#     'pressure': 1039.39,
#     'windSpeed': 2.89,
#     'windGust': 3.13,
#     'windBearing': 241,
#     'cloudCover': 0.96,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 305.12},
#    {'time': 1560297600,
#     'summary': 'Overcast',
#     'icon': 'cloudy',
#     'precipIntensity': 0.0002,
#     'precipProbability': 0.01,
#     'precipType': 'rain',
#     'temperature': 49.8,
#     'apparentTemperature': 49.8,
#     'dewPoint': 42.07,
#     'humidity': 0.75,
#     'pressure': 1039.56,
#     'windSpeed': 2.71,
#     'windGust': 3.09,
#     'windBearing': 252,
#     'cloudCover': 0.94,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 304.99},
#    {'time': 1560301200,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 48.91,
#     'apparentTemperature': 48.91,
#     'dewPoint': 42.24,
#     'humidity': 0.78,
#     'pressure': 1039.56,
#     'windSpeed': 2,
#     'windGust': 2.88,
#     'windBearing': 267,
#     'cloudCover': 0.83,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 304.29},
#    {'time': 1560304800,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 47.96,
#     'apparentTemperature': 47.96,
#     'dewPoint': 42.33,
#     'humidity': 0.81,
#     'pressure': 1039.56,
#     'windSpeed': 1.6,
#     'windGust': 2.65,
#     'windBearing': 234,
#     'cloudCover': 0.67,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 303.31},
#    {'time': 1560308400,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 47.22,
#     'apparentTemperature': 47.22,
#     'dewPoint': 42.43,
#     'humidity': 0.83,
#     'pressure': 1039.51,
#     'windSpeed': 1.36,
#     'windGust': 2.46,
#     'windBearing': 224,
#     'cloudCover': 0.56,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 302.43},
#    {'time': 1560312000,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 47.08,
#     'apparentTemperature': 47.08,
#     'dewPoint': 42.54,
#     'humidity': 0.84,
#     'pressure': 1039.5,
#     'windSpeed': 1.25,
#     'windGust': 2.31,
#     'windBearing': 184,
#     'cloudCover': 0.57,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 301.72},
#    {'time': 1560315600,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 47.27,
#     'apparentTemperature': 47.27,
#     'dewPoint': 42.65,
#     'humidity': 0.84,
#     'pressure': 1039.45,
#     'windSpeed': 1.34,
#     'windGust': 2.21,
#     'windBearing': 333,
#     'cloudCover': 0.63,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 301.23},
#    {'time': 1560319200,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 47.74,
#     'apparentTemperature': 47.74,
#     'dewPoint': 42.67,
#     'humidity': 0.82,
#     'pressure': 1039.37,
#     'windSpeed': 1.56,
#     'windGust': 2.29,
#     'windBearing': 281,
#     'cloudCover': 0.66,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 300.89},
#    {'time': 1560322800,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 48.67,
#     'apparentTemperature': 48.67,
#     'dewPoint': 42.54,
#     'humidity': 0.79,
#     'pressure': 1039.3,
#     'windSpeed': 1.79,
#     'windGust': 2.62,
#     'windBearing': 238,
#     'cloudCover': 0.62,
#     'uvIndex': 1,
#     'visibility': 10,
#     'ozone': 300.99},
#    {'time': 1560326400,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0003,
#     'precipProbability': 0.03,
#     'precipType': 'rain',
#     'temperature': 49.93,
#     'apparentTemperature': 49.93,
#     'dewPoint': 42.33,
#     'humidity': 0.75,
#     'pressure': 1039.2,
#     'windSpeed': 2.87,
#     'windGust': 3.17,
#     'windBearing': 328,
#     'cloudCover': 0.54,
#     'uvIndex': 1,
#     'visibility': 10,
#     'ozone': 301.34},
#    {'time': 1560330000,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0003,
#     'precipProbability': 0.03,
#     'precipType': 'rain',
#     'temperature': 51.19,
#     'apparentTemperature': 51.19,
#     'dewPoint': 42.2,
#     'humidity': 0.71,
#     'pressure': 1039.02,
#     'windSpeed': 3.97,
#     'windGust': 4.11,
#     'windBearing': 299,
#     'cloudCover': 0.49,
#     'uvIndex': 2,
#     'visibility': 10,
#     'ozone': 301.62},
#    {'time': 1560333600,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0002,
#     'precipProbability': 0.03,
#     'precipType': 'rain',
#     'temperature': 52.16,
#     'apparentTemperature': 52.16,
#     'dewPoint': 42.19,
#     'humidity': 0.69,
#     'pressure': 1038.75,
#     'windSpeed': 5.04,
#     'windGust': 5.3,
#     'windBearing': 293,
#     'cloudCover': 0.49,
#     'uvIndex': 3,
#     'visibility': 10,
#     'ozone': 301.69},
#    {'time': 1560337200,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 53.08,
#     'apparentTemperature': 53.08,
#     'dewPoint': 42.28,
#     'humidity': 0.67,
#     'pressure': 1038.45,
#     'windSpeed': 6.27,
#     'windGust': 6.66,
#     'windBearing': 298,
#     'cloudCover': 0.5,
#     'uvIndex': 4,
#     'visibility': 10,
#     'ozone': 301.79},
#    {'time': 1560340800,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 53.83,
#     'apparentTemperature': 53.83,
#     'dewPoint': 42.47,
#     'humidity': 0.65,
#     'pressure': 1038.11,
#     'windSpeed': 7.38,
#     'windGust': 7.93,
#     'windBearing': 304,
#     'cloudCover': 0.5,
#     'uvIndex': 4,
#     'visibility': 10,
#     'ozone': 302},
#    {'time': 1560344400,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 54.65,
#     'apparentTemperature': 54.65,
#     'dewPoint': 42.82,
#     'humidity': 0.64,
#     'pressure': 1037.78,
#     'windSpeed': 8.35,
#     'windGust': 9.07,
#     'windBearing': 306,
#     'cloudCover': 0.48,
#     'uvIndex': 5,
#     'visibility': 10,
#     'ozone': 302.4},
#    {'time': 1560348000,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 55.26,
#     'apparentTemperature': 55.26,
#     'dewPoint': 43.28,
#     'humidity': 0.64,
#     'pressure': 1037.41,
#     'windSpeed': 9.21,
#     'windGust': 10.12,
#     'windBearing': 308,
#     'cloudCover': 0.44,
#     'uvIndex': 5,
#     'visibility': 10,
#     'ozone': 302.93},
#    {'time': 1560351600,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 55.76,
#     'apparentTemperature': 55.76,
#     'dewPoint': 43.78,
#     'humidity': 0.64,
#     'pressure': 1037.02,
#     'windSpeed': 9.84,
#     'windGust': 11.02,
#     'windBearing': 309,
#     'cloudCover': 0.41,
#     'uvIndex': 4,
#     'visibility': 10,
#     'ozone': 303.5},
#    {'time': 1560355200,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 55.52,
#     'apparentTemperature': 55.52,
#     'dewPoint': 44.29,
#     'humidity': 0.66,
#     'pressure': 1036.63,
#     'windSpeed': 10.17,
#     'windGust': 11.8,
#     'windBearing': 310,
#     'cloudCover': 0.43,
#     'uvIndex': 4,
#     'visibility': 10,
#     'ozone': 304.23},
#    {'time': 1560358800,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0002,
#     'precipProbability': 0.02,
#     'precipType': 'rain',
#     'temperature': 54.78,
#     'apparentTemperature': 54.78,
#     'dewPoint': 44.86,
#     'humidity': 0.69,
#     'pressure': 1036.22,
#     'windSpeed': 10.24,
#     'windGust': 12.42,
#     'windBearing': 311,
#     'cloudCover': 0.47,
#     'uvIndex': 3,
#     'visibility': 10,
#     'ozone': 305.02},
#    {'time': 1560362400,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0003,
#     'precipProbability': 0.02,
#     'precipType': 'rain',
#     'temperature': 53.76,
#     'apparentTemperature': 53.76,
#     'dewPoint': 45.43,
#     'humidity': 0.73,
#     'pressure': 1035.85,
#     'windSpeed': 10.18,
#     'windGust': 12.77,
#     'windBearing': 311,
#     'cloudCover': 0.5,
#     'uvIndex': 2,
#     'visibility': 10,
#     'ozone': 306.22},
#    {'time': 1560366000,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0002,
#     'precipProbability': 0.01,
#     'precipType': 'rain',
#     'temperature': 53.1,
#     'apparentTemperature': 53.1,
#     'dewPoint': 46.04,
#     'humidity': 0.77,
#     'pressure': 1035.6,
#     'windSpeed': 10,
#     'windGust': 12.73,
#     'windBearing': 312,
#     'cloudCover': 0.52,
#     'uvIndex': 1,
#     'visibility': 10,
#     'ozone': 308.25},
#    {'time': 1560369600,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 52.61,
#     'apparentTemperature': 52.61,
#     'dewPoint': 46.66,
#     'humidity': 0.8,
#     'pressure': 1035.39,
#     'windSpeed': 9.71,
#     'windGust': 12.43,
#     'windBearing': 312,
#     'cloudCover': 0.54,
#     'uvIndex': 1,
#     'visibility': 10,
#     'ozone': 310.57},
#    {'time': 1560373200,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 52,
#     'apparentTemperature': 52,
#     'dewPoint': 47.14,
#     'humidity': 0.83,
#     'pressure': 1035.13,
#     'windSpeed': 9.32,
#     'windGust': 12.18,
#     'windBearing': 313,
#     'cloudCover': 0.57,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 312.21}]},
#  'daily': {'summary': 'No precipitation throughout the week, with high temperatures rising to 62°F on Friday.',
#   'icon': 'clear-day',
#   'data': [{'time': 1560124800,
#     'summary': 'Partly cloudy starting in the evening.',
#     'icon': 'partly-cloudy-day',
#     'sunriseTime': 1560135912,
#     'sunsetTime': 1560210726,
#     'moonPhase': 0.26,
#     'precipIntensity': 0.0001,
#     'precipIntensityMax': 0.0002,
#     'precipIntensityMaxTime': 1560157200,
#     'precipProbability': 0.06,
#     'precipType': 'rain',
#     'temperatureHigh': 55.19,
#     'temperatureHighTime': 1560182400,
#     'temperatureLow': 45.17,
#     'temperatureLowTime': 1560225600,
#     'apparentTemperatureHigh': 55.19,
#     'apparentTemperatureHighTime': 1560182400,
#     'apparentTemperatureLow': 45.17,
#     'apparentTemperatureLowTime': 1560225600,
#     'dewPoint': 39.67,
#     'humidity': 0.65,
#     'pressure': 1029.39,
#     'windSpeed': 3.62,
#     'windGust': 14.19,
#     'windGustTime': 1560178800,
#     'windBearing': 282,
#     'cloudCover': 0.26,
#     'uvIndex': 5,
#     'uvIndexTime': 1560171600,
#     'visibility': 6.21,
#     'ozone': 344.47,
#     'temperatureMin': 46.26,
#     'temperatureMinTime': 1560139200,
#     'temperatureMax': 55.19,
#     'temperatureMaxTime': 1560182400,
#     'apparentTemperatureMin': 41.45,
#     'apparentTemperatureMinTime': 1560139200,
#     'apparentTemperatureMax': 55.19,
#     'apparentTemperatureMaxTime': 1560182400},
#    {'time': 1560211200,
#     'summary': 'Mostly cloudy throughout the day.',
#     'icon': 'partly-cloudy-day',
#     'sunriseTime': 1560222217,
#     'sunsetTime': 1560297243,
#     'moonPhase': 0.3,
#     'precipIntensity': 0.0002,
#     'precipIntensityMax': 0.0004,
#     'precipIntensityMaxTime': 1560254400,
#     'precipProbability': 0.07,
#     'precipType': 'rain',
#     'temperatureHigh': 57.67,
#     'temperatureHighTime': 1560265200,
#     'temperatureLow': 47.08,
#     'temperatureLowTime': 1560312000,
#     'apparentTemperatureHigh': 57.67,
#     'apparentTemperatureHighTime': 1560265200,
#     'apparentTemperatureLow': 47.08,
#     'apparentTemperatureLowTime': 1560312000,
#     'dewPoint': 39.9,
#     'humidity': 0.66,
#     'pressure': 1036.65,
#     'windSpeed': 2.85,
#     'windGust': 6.71,
#     'windGustTime': 1560268800,
#     'windBearing': 266,
#     'cloudCover': 0.46,
#     'uvIndex': 4,
#     'uvIndexTime': 1560254400,
#     'visibility': 10,
#     'ozone': 314.61,
#     'temperatureMin': 45.17,
#     'temperatureMinTime': 1560225600,
#     'temperatureMax': 57.67,
#     'temperatureMaxTime': 1560265200,
#     'apparentTemperatureMin': 45.17,
#     'apparentTemperatureMinTime': 1560225600,
#     'apparentTemperatureMax': 57.67,
#     'apparentTemperatureMaxTime': 1560265200},
#    {'time': 1560297600,
#     'summary': 'Partly cloudy throughout the day.',
#     'icon': 'partly-cloudy-day',
#     'sunriseTime': 1560308531,
#     'sunsetTime': 1560383753,
#     'moonPhase': 0.33,
#     'precipIntensity': 0.0003,
#     'precipIntensityMax': 0.0022,
#     'precipIntensityMaxTime': 1560380400,
#     'precipProbability': 0.17,
#     'precipType': 'rain',
#     'temperatureHigh': 55.76,
#     'temperatureHighTime': 1560351600,
#     'temperatureLow': 49.35,
#     'temperatureLowTime': 1560394800,
#     'apparentTemperatureHigh': 55.76,
#     'apparentTemperatureHighTime': 1560351600,
#     'apparentTemperatureLow': 45.68,
#     'apparentTemperatureLowTime': 1560398400,
#     'dewPoint': 43.76,
#     'humidity': 0.75,
#     'pressure': 1037.73,
#     'windSpeed': 5.64,
#     'windGust': 12.77,
#     'windGustTime': 1560362400,
#     'windBearing': 305,
#     'cloudCover': 0.57,
#     'uvIndex': 5,
#     'uvIndexTime': 1560344400,
#     'visibility': 10,
#     'ozone': 304.5,
#     'temperatureMin': 47.08,
#     'temperatureMinTime': 1560312000,
#     'temperatureMax': 55.76,
#     'temperatureMaxTime': 1560351600,
#     'apparentTemperatureMin': 47.08,
#     'apparentTemperatureMinTime': 1560312000,
#     'apparentTemperatureMax': 55.76,
#     'apparentTemperatureMaxTime': 1560351600},
#    {'time': 1560384000,
#     'summary': 'Mostly cloudy throughout the day.',
#     'icon': 'partly-cloudy-day',
#     'sunriseTime': 1560394853,
#     'sunsetTime': 1560470254,
#     'moonPhase': 0.37,
#     'precipIntensity': 0.004,
#     'precipIntensityMax': 0.0153,
#     'precipIntensityMaxTime': 1560405600,
#     'precipProbability': 0.18,
#     'precipType': 'rain',
#     'temperatureHigh': 57.27,
#     'temperatureHighTime': 1560452400,
#     'temperatureLow': 48.33,
#     'temperatureLowTime': 1560484800,
#     'apparentTemperatureHigh': 57.27,
#     'apparentTemperatureHighTime': 1560452400,
#     'apparentTemperatureLow': 46.77,
#     'apparentTemperatureLowTime': 1560481200,
#     'dewPoint': 47.32,
#     'humidity': 0.83,
#     'pressure': 1026.44,
#     'windSpeed': 10.98,
#     'windGust': 26.1,
#     'windGustTime': 1560438000,
#     'windBearing': 327,
#     'cloudCover': 0.85,
#     'uvIndex': 3,
#     'uvIndexTime': 1560423600,
#     'visibility': 9.23,
#     'ozone': 313.02,
#     'temperatureMin': 49.35,
#     'temperatureMinTime': 1560394800,
#     'temperatureMax': 57.98,
#     'temperatureMaxTime': 1560456000,
#     'apparentTemperatureMin': 45.68,
#     'apparentTemperatureMinTime': 1560398400,
#     'apparentTemperatureMax': 57.98,
#     'apparentTemperatureMaxTime': 1560456000},
#    {'time': 1560470400,
#     'summary': 'Partly cloudy in the morning.',
#     'icon': 'partly-cloudy-day',
#     'sunriseTime': 1560481185,
#     'sunsetTime': 1560556746,
#     'moonPhase': 0.41,
#     'precipIntensity': 0.0006,
#     'precipIntensityMax': 0.0062,
#     'precipIntensityMaxTime': 1560492000,
#     'precipProbability': 0.07,
#     'precipType': 'rain',
#     'temperatureHigh': 62.11,
#     'temperatureHighTime': 1560531600,
#     'temperatureLow': 50.69,
#     'temperatureLowTime': 1560571200,
#     'apparentTemperatureHigh': 62.11,
#     'apparentTemperatureHighTime': 1560531600,
#     'apparentTemperatureLow': 50.69,
#     'apparentTemperatureLowTime': 1560571200,
#     'dewPoint': 41.09,
#     'humidity': 0.6,
#     'pressure': 1017.06,
#     'windSpeed': 6.65,
#     'windGust': 18.34,
#     'windGustTime': 1560546000,
#     'windBearing': 19,
#     'cloudCover': 0.28,
#     'uvIndex': 5,
#     'uvIndexTime': 1560517200,
#     'visibility': 10,
#     'ozone': 346.38,
#     'temperatureMin': 48.33,
#     'temperatureMinTime': 1560484800,
#     'temperatureMax': 62.11,
#     'temperatureMaxTime': 1560531600,
#     'apparentTemperatureMin': 46.77,
#     'apparentTemperatureMinTime': 1560481200,
#     'apparentTemperatureMax': 62.11,
#     'apparentTemperatureMaxTime': 1560531600},
#    {'time': 1560556800,
#     'summary': 'Mostly cloudy throughout the day.',
#     'icon': 'partly-cloudy-day',
#     'sunriseTime': 1560567526,
#     'sunsetTime': 1560643229,
#     'moonPhase': 0.44,
#     'precipIntensity': 0.0011,
#     'precipIntensityMax': 0.0043,
#     'precipIntensityMaxTime': 1560600000,
#     'precipProbability': 0.17,
#     'precipType': 'rain',
#     'temperatureHigh': 60.26,
#     'temperatureHighTime': 1560614400,
#     'temperatureLow': 51.05,
#     'temperatureLowTime': 1560654000,
#     'apparentTemperatureHigh': 60.26,
#     'apparentTemperatureHighTime': 1560614400,
#     'apparentTemperatureLow': 51.05,
#     'apparentTemperatureLowTime': 1560654000,
#     'dewPoint': 43.05,
#     'humidity': 0.63,
#     'pressure': 1011.57,
#     'windSpeed': 6.4,
#     'windGust': 15.88,
#     'windGustTime': 1560632400,
#     'windBearing': 358,
#     'cloudCover': 0.66,
#     'uvIndex': 3,
#     'uvIndexTime': 1560596400,
#     'visibility': 10,
#     'ozone': 342.39,
#     'temperatureMin': 50.69,
#     'temperatureMinTime': 1560571200,
#     'temperatureMax': 60.26,
#     'temperatureMaxTime': 1560614400,
#     'apparentTemperatureMin': 50.69,
#     'apparentTemperatureMinTime': 1560571200,
#     'apparentTemperatureMax': 60.26,
#     'apparentTemperatureMaxTime': 1560614400},
#    {'time': 1560643200,
#     'summary': 'Mostly cloudy throughout the day.',
#     'icon': 'partly-cloudy-day',
#     'sunriseTime': 1560653877,
#     'sunsetTime': 1560729703,
#     'moonPhase': 0.47,
#     'precipIntensity': 0.0027,
#     'precipIntensityMax': 0.0094,
#     'precipIntensityMaxTime': 1560726000,
#     'precipProbability': 0.56,
#     'precipType': 'rain',
#     'temperatureHigh': 57.45,
#     'temperatureHighTime': 1560686400,
#     'temperatureLow': 50.95,
#     'temperatureLowTime': 1560740400,
#     'apparentTemperatureHigh': 57.45,
#     'apparentTemperatureHighTime': 1560686400,
#     'apparentTemperatureLow': 50.95,
#     'apparentTemperatureLowTime': 1560740400,
#     'dewPoint': 44.46,
#     'humidity': 0.71,
#     'pressure': 1009.43,
#     'windSpeed': 3.82,
#     'windGust': 15.63,
#     'windGustTime': 1560711600,
#     'windBearing': 32,
#     'cloudCover': 0.7,
#     'uvIndex': 3,
#     'uvIndexTime': 1560682800,
#     'visibility': 9.29,
#     'ozone': 339.95,
#     'temperatureMin': 51.05,
#     'temperatureMinTime': 1560654000,
#     'temperatureMax': 57.45,
#     'temperatureMaxTime': 1560686400,
#     'apparentTemperatureMin': 51.05,
#     'apparentTemperatureMinTime': 1560654000,
#     'apparentTemperatureMax': 57.45,
#     'apparentTemperatureMaxTime': 1560686400},
#    {'time': 1560729600,
#     'summary': 'Overcast throughout the day.',
#     'icon': 'cloudy',
#     'sunriseTime': 1560740238,
#     'sunsetTime': 1560816166,
#     'moonPhase': 0.51,
#     'precipIntensity': 0.0044,
#     'precipIntensityMax': 0.0117,
#     'precipIntensityMaxTime': 1560805200,
#     'precipProbability': 0.69,
#     'precipType': 'rain',
#     'temperatureHigh': 56.68,
#     'temperatureHighTime': 1560787200,
#     'temperatureLow': 51.26,
#     'temperatureLowTime': 1560826800,
#     'apparentTemperatureHigh': 56.68,
#     'apparentTemperatureHighTime': 1560787200,
#     'apparentTemperatureLow': 51.26,
#     'apparentTemperatureLowTime': 1560826800,
#     'dewPoint': 44.16,
#     'humidity': 0.71,
#     'pressure': 1009.21,
#     'windSpeed': 5.02,
#     'windGust': 21.29,
#     'windGustTime': 1560812400,
#     'windBearing': 84,
#     'cloudCover': 0.94,
#     'uvIndex': 3,
#     'uvIndexTime': 1560769200,
#     'visibility': 9.21,
#     'ozone': 345.78,
#     'temperatureMin': 50.95,
#     'temperatureMinTime': 1560740400,
#     'temperatureMax': 56.68,
#     'temperatureMaxTime': 1560787200,
#     'apparentTemperatureMin': 50.95,
#     'apparentTemperatureMinTime': 1560740400,
#     'apparentTemperatureMax': 56.68,
#     'apparentTemperatureMaxTime': 1560787200}]},
#  'flags': {'sources': ['imo', 'cmc', 'gfs', 'icon', 'isd', 'madis'],
#   'nearest-station': 1.148,
#   'units': 'us'},
#  'offset': 0}

# %%
Reykjavik.keys()
# Out:
# dict_keys(['latitude', 'longitude', 'timezone', 'currently', 'hourly', 'daily', 'flags', 'offset'])

# %%
Reykjavik['daily']['data'][0]['moonPhase']
# Out:
# 0.26

# %% [markdown]
# ## 4) What's the difference between the high and low temperatures for today?

# %%
Reykjavik['daily']
# Out:
# {'summary': 'No precipitation throughout the week, with high temperatures rising to 62°F on Friday.',
#  'icon': 'clear-day',
#  'data': [{'time': 1560124800,
#    'summary': 'Partly cloudy starting in the evening.',
#    'icon': 'partly-cloudy-day',
#    'sunriseTime': 1560135912,
#    'sunsetTime': 1560210726,
#    'moonPhase': 0.26,
#    'precipIntensity': 0.0001,
#    'precipIntensityMax': 0.0002,
#    'precipIntensityMaxTime': 1560157200,
#    'precipProbability': 0.06,
#    'precipType': 'rain',
#    'temperatureHigh': 55.19,
#    'temperatureHighTime': 1560182400,
#    'temperatureLow': 45.17,
#    'temperatureLowTime': 1560225600,
#    'apparentTemperatureHigh': 55.19,
#    'apparentTemperatureHighTime': 1560182400,
#    'apparentTemperatureLow': 45.17,
#    'apparentTemperatureLowTime': 1560225600,
#    'dewPoint': 39.67,
#    'humidity': 0.65,
#    'pressure': 1029.39,
#    'windSpeed': 3.62,
#    'windGust': 14.19,
#    'windGustTime': 1560178800,
#    'windBearing': 282,
#    'cloudCover': 0.26,
#    'uvIndex': 5,
#    'uvIndexTime': 1560171600,
#    'visibility': 6.21,
#    'ozone': 344.47,
#    'temperatureMin': 46.26,
#    'temperatureMinTime': 1560139200,
#    'temperatureMax': 55.19,
#    'temperatureMaxTime': 1560182400,
#    'apparentTemperatureMin': 41.45,
#    'apparentTemperatureMinTime': 1560139200,
#    'apparentTemperatureMax': 55.19,
#    'apparentTemperatureMaxTime': 1560182400},
#   {'time': 1560211200,
#    'summary': 'Mostly cloudy throughout the day.',
#    'icon': 'partly-cloudy-day',
#    'sunriseTime': 1560222217,
#    'sunsetTime': 1560297243,
#    'moonPhase': 0.3,
#    'precipIntensity': 0.0002,
#    'precipIntensityMax': 0.0004,
#    'precipIntensityMaxTime': 1560254400,
#    'precipProbability': 0.07,
#    'precipType': 'rain',
#    'temperatureHigh': 57.67,
#    'temperatureHighTime': 1560265200,
#    'temperatureLow': 47.08,
#    'temperatureLowTime': 1560312000,
#    'apparentTemperatureHigh': 57.67,
#    'apparentTemperatureHighTime': 1560265200,
#    'apparentTemperatureLow': 47.08,
#    'apparentTemperatureLowTime': 1560312000,
#    'dewPoint': 39.9,
#    'humidity': 0.66,
#    'pressure': 1036.65,
#    'windSpeed': 2.85,
#    'windGust': 6.71,
#    'windGustTime': 1560268800,
#    'windBearing': 266,
#    'cloudCover': 0.46,
#    'uvIndex': 4,
#    'uvIndexTime': 1560254400,
#    'visibility': 10,
#    'ozone': 314.61,
#    'temperatureMin': 45.17,
#    'temperatureMinTime': 1560225600,
#    'temperatureMax': 57.67,
#    'temperatureMaxTime': 1560265200,
#    'apparentTemperatureMin': 45.17,
#    'apparentTemperatureMinTime': 1560225600,
#    'apparentTemperatureMax': 57.67,
#    'apparentTemperatureMaxTime': 1560265200},
#   {'time': 1560297600,
#    'summary': 'Partly cloudy throughout the day.',
#    'icon': 'partly-cloudy-day',
#    'sunriseTime': 1560308531,
#    'sunsetTime': 1560383753,
#    'moonPhase': 0.33,
#    'precipIntensity': 0.0003,
#    'precipIntensityMax': 0.0022,
#    'precipIntensityMaxTime': 1560380400,
#    'precipProbability': 0.17,
#    'precipType': 'rain',
#    'temperatureHigh': 55.76,
#    'temperatureHighTime': 1560351600,
#    'temperatureLow': 49.35,
#    'temperatureLowTime': 1560394800,
#    'apparentTemperatureHigh': 55.76,
#    'apparentTemperatureHighTime': 1560351600,
#    'apparentTemperatureLow': 45.68,
#    'apparentTemperatureLowTime': 1560398400,
#    'dewPoint': 43.76,
#    'humidity': 0.75,
#    'pressure': 1037.73,
#    'windSpeed': 5.64,
#    'windGust': 12.77,
#    'windGustTime': 1560362400,
#    'windBearing': 305,
#    'cloudCover': 0.57,
#    'uvIndex': 5,
#    'uvIndexTime': 1560344400,
#    'visibility': 10,
#    'ozone': 304.5,
#    'temperatureMin': 47.08,
#    'temperatureMinTime': 1560312000,
#    'temperatureMax': 55.76,
#    'temperatureMaxTime': 1560351600,
#    'apparentTemperatureMin': 47.08,
#    'apparentTemperatureMinTime': 1560312000,
#    'apparentTemperatureMax': 55.76,
#    'apparentTemperatureMaxTime': 1560351600},
#   {'time': 1560384000,
#    'summary': 'Mostly cloudy throughout the day.',
#    'icon': 'partly-cloudy-day',
#    'sunriseTime': 1560394853,
#    'sunsetTime': 1560470254,
#    'moonPhase': 0.37,
#    'precipIntensity': 0.004,
#    'precipIntensityMax': 0.0153,
#    'precipIntensityMaxTime': 1560405600,
#    'precipProbability': 0.18,
#    'precipType': 'rain',
#    'temperatureHigh': 57.27,
#    'temperatureHighTime': 1560452400,
#    'temperatureLow': 48.33,
#    'temperatureLowTime': 1560484800,
#    'apparentTemperatureHigh': 57.27,
#    'apparentTemperatureHighTime': 1560452400,
#    'apparentTemperatureLow': 46.77,
#    'apparentTemperatureLowTime': 1560481200,
#    'dewPoint': 47.32,
#    'humidity': 0.83,
#    'pressure': 1026.44,
#    'windSpeed': 10.98,
#    'windGust': 26.1,
#    'windGustTime': 1560438000,
#    'windBearing': 327,
#    'cloudCover': 0.85,
#    'uvIndex': 3,
#    'uvIndexTime': 1560423600,
#    'visibility': 9.23,
#    'ozone': 313.02,
#    'temperatureMin': 49.35,
#    'temperatureMinTime': 1560394800,
#    'temperatureMax': 57.98,
#    'temperatureMaxTime': 1560456000,
#    'apparentTemperatureMin': 45.68,
#    'apparentTemperatureMinTime': 1560398400,
#    'apparentTemperatureMax': 57.98,
#    'apparentTemperatureMaxTime': 1560456000},
#   {'time': 1560470400,
#    'summary': 'Partly cloudy in the morning.',
#    'icon': 'partly-cloudy-day',
#    'sunriseTime': 1560481185,
#    'sunsetTime': 1560556746,
#    'moonPhase': 0.41,
#    'precipIntensity': 0.0006,
#    'precipIntensityMax': 0.0062,
#    'precipIntensityMaxTime': 1560492000,
#    'precipProbability': 0.07,
#    'precipType': 'rain',
#    'temperatureHigh': 62.11,
#    'temperatureHighTime': 1560531600,
#    'temperatureLow': 50.69,
#    'temperatureLowTime': 1560571200,
#    'apparentTemperatureHigh': 62.11,
#    'apparentTemperatureHighTime': 1560531600,
#    'apparentTemperatureLow': 50.69,
#    'apparentTemperatureLowTime': 1560571200,
#    'dewPoint': 41.09,
#    'humidity': 0.6,
#    'pressure': 1017.06,
#    'windSpeed': 6.65,
#    'windGust': 18.34,
#    'windGustTime': 1560546000,
#    'windBearing': 19,
#    'cloudCover': 0.28,
#    'uvIndex': 5,
#    'uvIndexTime': 1560517200,
#    'visibility': 10,
#    'ozone': 346.38,
#    'temperatureMin': 48.33,
#    'temperatureMinTime': 1560484800,
#    'temperatureMax': 62.11,
#    'temperatureMaxTime': 1560531600,
#    'apparentTemperatureMin': 46.77,
#    'apparentTemperatureMinTime': 1560481200,
#    'apparentTemperatureMax': 62.11,
#    'apparentTemperatureMaxTime': 1560531600},
#   {'time': 1560556800,
#    'summary': 'Mostly cloudy throughout the day.',
#    'icon': 'partly-cloudy-day',
#    'sunriseTime': 1560567526,
#    'sunsetTime': 1560643229,
#    'moonPhase': 0.44,
#    'precipIntensity': 0.0011,
#    'precipIntensityMax': 0.0043,
#    'precipIntensityMaxTime': 1560600000,
#    'precipProbability': 0.17,
#    'precipType': 'rain',
#    'temperatureHigh': 60.26,
#    'temperatureHighTime': 1560614400,
#    'temperatureLow': 51.05,
#    'temperatureLowTime': 1560654000,
#    'apparentTemperatureHigh': 60.26,
#    'apparentTemperatureHighTime': 1560614400,
#    'apparentTemperatureLow': 51.05,
#    'apparentTemperatureLowTime': 1560654000,
#    'dewPoint': 43.05,
#    'humidity': 0.63,
#    'pressure': 1011.57,
#    'windSpeed': 6.4,
#    'windGust': 15.88,
#    'windGustTime': 1560632400,
#    'windBearing': 358,
#    'cloudCover': 0.66,
#    'uvIndex': 3,
#    'uvIndexTime': 1560596400,
#    'visibility': 10,
#    'ozone': 342.39,
#    'temperatureMin': 50.69,
#    'temperatureMinTime': 1560571200,
#    'temperatureMax': 60.26,
#    'temperatureMaxTime': 1560614400,
#    'apparentTemperatureMin': 50.69,
#    'apparentTemperatureMinTime': 1560571200,
#    'apparentTemperatureMax': 60.26,
#    'apparentTemperatureMaxTime': 1560614400},
#   {'time': 1560643200,
#    'summary': 'Mostly cloudy throughout the day.',
#    'icon': 'partly-cloudy-day',
#    'sunriseTime': 1560653877,
#    'sunsetTime': 1560729703,
#    'moonPhase': 0.47,
#    'precipIntensity': 0.0027,
#    'precipIntensityMax': 0.0094,
#    'precipIntensityMaxTime': 1560726000,
#    'precipProbability': 0.56,
#    'precipType': 'rain',
#    'temperatureHigh': 57.45,
#    'temperatureHighTime': 1560686400,
#    'temperatureLow': 50.95,
#    'temperatureLowTime': 1560740400,
#    'apparentTemperatureHigh': 57.45,
#    'apparentTemperatureHighTime': 1560686400,
#    'apparentTemperatureLow': 50.95,
#    'apparentTemperatureLowTime': 1560740400,
#    'dewPoint': 44.46,
#    'humidity': 0.71,
#    'pressure': 1009.43,
#    'windSpeed': 3.82,
#    'windGust': 15.63,
#    'windGustTime': 1560711600,
#    'windBearing': 32,
#    'cloudCover': 0.7,
#    'uvIndex': 3,
#    'uvIndexTime': 1560682800,
#    'visibility': 9.29,
#    'ozone': 339.95,
#    'temperatureMin': 51.05,
#    'temperatureMinTime': 1560654000,
#    'temperatureMax': 57.45,
#    'temperatureMaxTime': 1560686400,
#    'apparentTemperatureMin': 51.05,
#    'apparentTemperatureMinTime': 1560654000,
#    'apparentTemperatureMax': 57.45,
#    'apparentTemperatureMaxTime': 1560686400},
#   {'time': 1560729600,
#    'summary': 'Overcast throughout the day.',
#    'icon': 'cloudy',
#    'sunriseTime': 1560740238,
#    'sunsetTime': 1560816166,
#    'moonPhase': 0.51,
#    'precipIntensity': 0.0044,
#    'precipIntensityMax': 0.0117,
#    'precipIntensityMaxTime': 1560805200,
#    'precipProbability': 0.69,
#    'precipType': 'rain',
#    'temperatureHigh': 56.68,
#    'temperatureHighTime': 1560787200,
#    'temperatureLow': 51.26,
#    'temperatureLowTime': 1560826800,
#    'apparentTemperatureHigh': 56.68,
#    'apparentTemperatureHighTime': 1560787200,
#    'apparentTemperatureLow': 51.26,
#    'apparentTemperatureLowTime': 1560826800,
#    'dewPoint': 44.16,
#    'humidity': 0.71,
#    'pressure': 1009.21,
#    'windSpeed': 5.02,
#    'windGust': 21.29,
#    'windGustTime': 1560812400,
#    'windBearing': 84,
#    'cloudCover': 0.94,
#    'uvIndex': 3,
#    'uvIndexTime': 1560769200,
#    'visibility': 9.21,
#    'ozone': 345.78,
#    'temperatureMin': 50.95,
#    'temperatureMinTime': 1560740400,
#    'temperatureMax': 56.68,
#    'temperatureMaxTime': 1560787200,
#    'apparentTemperatureMin': 50.95,
#    'apparentTemperatureMinTime': 1560740400,
#    'apparentTemperatureMax': 56.68,
#    'apparentTemperatureMaxTime': 1560787200}]}

# %%
temp_dif = round(Reykjavik['daily']['data'][0]['temperatureMax'] - Reykjavik['daily']['data'][0]['temperatureMin'])
temp_dif
# Out:
# 9

# %% [markdown]
# ## 5) Go through the daily forecasts, printing out the next week's worth of predictions.
#
# I'd like to know the **high temperature** for each day, and whether it's **hot, warm, or cold** (based on what temperatures you think are hot, warm or cold).
#
# - *Tip: Is it returning F or C? You can change them by adding `?units=us` or `?units=si` onto the end of the URL.*
# - *Tip: You'll need to use an `if` statement to say whether it is hot, warm or cold.*

# %%
for forecast in Reykjavik['daily']['data']:
    print(forecast["summary"])
# Out:
# Partly cloudy starting in the evening.
# Mostly cloudy throughout the day.
# Partly cloudy throughout the day.
# Mostly cloudy throughout the day.
# Partly cloudy in the morning.
# Mostly cloudy throughout the day.
# Mostly cloudy throughout the day.
# Overcast throughout the day.

# %%
for forecast in Reykjavik['daily']['data']:
    if forecast['temperatureHigh'] > 80:
        print (forecast['temperatureHigh'], "is hot")
    if forecast['temperatureHigh'] > 60:
        print (forecast['temperatureHigh'], "is warm")
    else:
        print(forecast['temperatureHigh'], "is cold")
# Out:
# 55.19 is cold
# 57.68 is cold
# 55.76 is cold
# 57.27 is cold
# 62.12 is warm
# 60.26 is warm
# 57.45 is cold
# 56.68 is cold

# %% [markdown]
# # 6) What will be the hottest day in the next week? What is the high temperature on that day?
#
# It's okay if your result looks like `1453363200`. If you want to be extra-fancy, though, format it as a **real date** - the weird number is called a **UNIX timestamp**, which might help in googling.
#
# - *Tip: It's okay to skip this if it seems too difficult!*

# %% [markdown]
# ## 7) What's the weather looking like for the next 24+ hours in Miami, Florida?
#
# I'd like to know the temperature for every hour, and if it's going to have cloud cover of more than 50% say "{temperature} and cloudy" instead of just the temperature.
#
#
# - *Tip: Be sure to remember how latitude and longitude are done with positive and negative numbers*
# - *Tip: How do you represent "50%" for cloud cover?*

# %% [markdown]
# # 8) For the next 24-ish hours in Miami, what percent of the time is the temperature above 85 degrees?
#
# If they give you 48 hours instead of 24, that's okay.
#
# - *Tip: You might want to read up on [looping patterns](http://jonathansoma.com/lede/foundations-2017/classes/data%20structures/looping-patterns/)*

# %% [markdown]
# ## 9) What was the temperature in Central Park on Christmas Day, 2012? How about 2007? 2005? How far back does the API allow you to go?
#
# - *Tip: You'll need to use UNIX time, which is the number of seconds since January 1, 1970. Google can help you convert a normal date!*
# - *Tip: You'll want to use Forecast.io's "time machine" API, [documentation here](https://darksky.net/dev/docs/time-machine)*
